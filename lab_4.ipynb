# %%
#подключение к гугл диску
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from skimage import io
import os

def download_data(path):
  data = []
  for path_image in sorted(os.listdir(path=path)):
    image = Image.open(path + path_image) #Открываем изображение.
    data.append(np.array(image)) #Загружаем пиксели.
  return data

X_train = download_data(r"./drive/My Drive/lab4/train/images/")
Y_train = download_data(r"./drive/My Drive/lab4/train/masks/")
X_test = download_data(r"./drive/My Drive/lab4/test/images/")
Y_test = download_data(r"./drive/My Drive/lab4/test/masks/")

# %%
palette = {0 : (60, 16, 152), # Building
           1 : (132, 41, 246), # Land
           2 : (110, 193, 228), # Road
           3 : (254, 221, 58), # Vegetation
           4 : (226, 169, 41), # Water
           5 : (155, 155, 155)} # Unlabeled

invert_palette = {v: k for k, v in palette.items()}

# сегментация нейронной сети в RGB изображение
def convert_to_color(arr_2d, palette=palette):
    """ Numeric labels to RGB-color encoding """
    arr_3d = np.zeros((arr_2d.shape[0], arr_2d.shape[1], 3), dtype=np.uint8)

    for c, i in palette.items():
        m = arr_2d == c
        arr_3d[m] = i

    return arr_3d

# %%
# преобразование сегментированного image in answer network for input in output
def convert_from_color(arr_3d, palette=invert_palette):
    """ RGB-color encoding to grayscale labels """
    arr_2d = np.zeros((arr_3d.shape[0], arr_3d.shape[1]), dtype=np.uint8)

    arr_2d = np.zeros((arr_3d.shape[0], arr_3d.shape[1]), dtype=np.int8) # принадлежность каждого пикселя классу
    min_distance = np.zeros((arr_3d.shape[0], arr_3d.shape[1]), dtype=np.float32)+1000 # расстояние до ближайшего класса для пикселей
    for c, i in palette.items():
      distance = np.sum((arr_3d - np.array(c).reshape(1, 1, 3))**2, axis=-1)**(1/2) # ищем расстояние для каждого пикселя до проверяемого класса по евклиду рас-ие
      condition = min_distance > distance # поиск элементов меньше min_distance
      min_distance[condition] = distance[condition] # замена дистанции найденных элементов
      arr_2d[condition] = i # замена класса найденных элементов

    for c, i in palette.items():
      m = np.all(arr_3d == np.array(c).reshape(1, 1, 3), axis=2)
      arr_2d[m] = i

    arr_2d = arr_2d.tolist()
    for i in range(len(arr_2d)):
      for j in range(len(arr_2d[0])):
        label = [0, 0, 0, 0, 0, 0]
        label[arr_2d[i][j]] = 1
        arr_2d[i][j] = label
    arr_2d = np.array(arr_2d)

    return arr_2d

# %%
X_train_pred = np.array(X_train).reshape([7, 644, 796, 3])/255
X_test_pred = np.array(X_test).reshape([2, 644, 796, 3])/255
Y_train_pred = []
for i in range(len(Y_train)):
  Y_train_pred.append(convert_from_color(Y_train[i][:, :, :3]))
Y_train_pred = np.array(Y_train_pred)
Y_test_pred = []
for i in range(len(Y_test)):
  Y_test_pred.append(convert_from_color(Y_test[i][:, :, :3]))
Y_test_pred = np.array(Y_test_pred)

# %%
import numpy as np 
from keras.models import *
from keras.layers import *
from keras.optimizers import *

inputs = Input([644, 796, 3])
conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same')(inputs)
conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same')(conv1)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

conv2 = Conv2D(64, 5, activation = 'relu', padding = 'same')(pool1)
conv2 = Conv2D(64, 5, activation = 'relu', padding = 'same')(conv2)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

conv3 = Conv2D(128, 7, activation = 'relu', padding = 'same')(pool2)
conv3 = Conv2D(128, 7, activation = 'relu', padding = 'same')(conv3)

up1 = UpSampling2D(size = (2,2))(conv3)
merge1 = concatenate([conv2, up1], axis = 3)
conv4 = Conv2D(64, 5, activation = 'relu', padding = 'same')(merge1)
conv4 = Conv2D(64, 5, activation = 'relu', padding = 'same')(conv4)

up2 = UpSampling2D(size = (2,2))(conv4)
merge1 = concatenate([conv1, up2], axis = 3)
conv5 = Conv2D(32, 3, activation = 'relu', padding = 'same')(merge1)
conv5 = Conv2D(32, 3, activation = 'relu', padding = 'same')(conv5)

conv6 = Conv2D(6, 3, activation = 'softmax', padding = 'same')(conv5)

model = Model(inputs = inputs, outputs = conv6)

model.compile(optimizer = Adam(), loss = 'categorical_crossentropy')

# %%
model.fit(X_train_pred,Y_train_pred, epochs = 200, batch_size = 10 )
# Out:
# Epoch 1/200
# 1/1 [==============================] - 2s 2s/step - loss: 1.2983
# Epoch 2/200
# 1/1 [==============================] - 2s 2s/step - loss: 1.0826
# Epoch 3/200
# 1/1 [==============================] - 2s 2s/step - loss: 1.3690
# Epoch 4/200
# 1/1 [==============================] - 2s 2s/step - loss: 1.0723
# Epoch 5/200
# 1/1 [==============================] - 2s 2s/step - loss: 1.1473
# Epoch 6/200
# 1/1 [==============================] - 2s 2s/step - loss: 1.1688
# Epoch 7/200
# 1/1 [==============================] - 2s 2s/step - loss: 1.0904
# Epoch 8/200
# 1/1 [==============================] - 2s 2s/step - loss: 1.0132
# Epoch 9/200
# 1/1 [==============================] - 2s 2s/step - loss: 1.0289
# Epoch 10/200
# 1/1 [==============================] - 2s 2s/step - loss: 1.0484
# Epoch 11/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.9973
# Epoch 12/200
# 1/1 [==============================] - 2s 2s/step - loss: 1.0026
# Epoch 13/200
# 1/1 [==============================] - 2s 2s/step - loss: 1.0043
# Epoch 14/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.9805
# Epoch 15/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.9779
# Epoch 16/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.9828
# Epoch 17/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.9705
# Epoch 18/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.9681
# Epoch 19/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.9647
# Epoch 20/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.9576
# Epoch 21/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.9577
# Epoch 22/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.9524
# Epoch 23/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.9541
# Epoch 24/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.9478
# Epoch 25/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.9460
# Epoch 26/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.9355
# Epoch 27/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.9325
# Epoch 28/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.9250
# Epoch 29/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.9286
# Epoch 30/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.9093
# Epoch 31/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.9246
# Epoch 32/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.8996
# Epoch 33/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.9012
# Epoch 34/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.8698
# Epoch 35/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.8658
# Epoch 36/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.8304
# Epoch 37/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.7941
# Epoch 38/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.7504
# Epoch 39/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.7515
# Epoch 40/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.8392
# Epoch 41/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.8093
# Epoch 42/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.7731
# Epoch 43/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.7518
# Epoch 44/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.7389
# Epoch 45/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.7429
# Epoch 46/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.7482
# Epoch 47/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.7224
# Epoch 48/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.7037
# Epoch 49/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.6960
# Epoch 50/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.6871
# Epoch 51/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.6826
# Epoch 52/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.6740
# Epoch 53/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.7110
# Epoch 54/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.6761
# Epoch 55/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.6535
# Epoch 56/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.6614
# Epoch 57/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.6375
# Epoch 58/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.6320
# Epoch 59/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.6311
# Epoch 60/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.6233
# Epoch 61/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.6122
# Epoch 62/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5966
# Epoch 63/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.6005
# Epoch 64/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.6118
# Epoch 65/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.6017
# Epoch 66/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5840
# Epoch 67/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5757
# Epoch 68/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5711
# Epoch 69/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5718
# Epoch 70/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5796
# Epoch 71/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5716
# Epoch 72/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5927
# Epoch 73/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.6128
# Epoch 74/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.6225
# Epoch 75/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5562
# Epoch 76/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5959
# Epoch 77/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5808
# Epoch 78/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5672
# Epoch 79/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5565
# Epoch 80/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5626
# Epoch 81/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5499
# Epoch 82/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5415
# Epoch 83/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5464
# Epoch 84/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5415
# Epoch 85/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5294
# Epoch 86/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5233
# Epoch 87/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5225
# Epoch 88/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5120
# Epoch 89/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5105
# Epoch 90/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5055
# Epoch 91/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5055
# Epoch 92/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5594
# Epoch 93/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.6644
# Epoch 94/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5272
# Epoch 95/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5868
# Epoch 96/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5738
# Epoch 97/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5883
# Epoch 98/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5469
# Epoch 99/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5582
# Epoch 100/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5332
# Epoch 101/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5231
# Epoch 102/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5182
# Epoch 103/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5219
# Epoch 104/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5336
# Epoch 105/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5272
# Epoch 106/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5066
# Epoch 107/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5135
# Epoch 108/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.5134
# Epoch 109/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4883
# Epoch 110/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4991
# Epoch 111/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4821
# Epoch 112/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4859
# Epoch 113/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4786
# Epoch 114/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4809
# Epoch 115/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4721
# Epoch 116/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4746
# Epoch 117/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4688
# Epoch 118/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4666
# Epoch 119/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4626
# Epoch 120/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4621
# Epoch 121/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4552
# Epoch 122/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4564
# Epoch 123/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4525
# Epoch 124/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4492
# Epoch 125/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4506
# Epoch 126/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4465
# Epoch 127/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4428
# Epoch 128/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4423
# Epoch 129/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4402
# Epoch 130/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4367
# Epoch 131/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4344
# Epoch 132/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4322
# Epoch 133/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4291
# Epoch 134/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4268
# Epoch 135/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4271
# Epoch 136/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4318
# Epoch 137/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4527
# Epoch 138/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4316
# Epoch 139/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4221
# Epoch 140/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4285
# Epoch 141/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4319
# Epoch 142/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4187
# Epoch 143/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4178
# Epoch 144/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4211
# Epoch 145/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4253
# Epoch 146/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4128
# Epoch 147/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4354
# Epoch 148/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4640
# Epoch 149/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4616
# Epoch 150/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4527
# Epoch 151/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4447
# Epoch 152/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4420
# Epoch 153/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4373
# Epoch 154/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4418
# Epoch 155/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4294
# Epoch 156/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4276
# Epoch 157/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4241
# Epoch 158/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4172
# Epoch 159/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4179
# Epoch 160/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4149
# Epoch 161/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4174
# Epoch 162/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4142
# Epoch 163/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4082
# Epoch 164/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4004
# Epoch 165/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4043
# Epoch 166/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4012
# Epoch 167/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3957
# Epoch 168/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3931
# Epoch 169/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3924
# Epoch 170/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3906
# Epoch 171/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3893
# Epoch 172/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3930
# Epoch 173/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3973
# Epoch 174/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3866
# Epoch 175/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3816
# Epoch 176/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3818
# Epoch 177/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3803
# Epoch 178/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3680
# Epoch 179/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3772
# Epoch 180/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3845
# Epoch 181/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3773
# Epoch 182/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3756
# Epoch 183/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4166
# Epoch 184/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4590
# Epoch 185/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4287
# Epoch 186/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4207
# Epoch 187/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4154
# Epoch 188/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3957
# Epoch 189/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4003
# Epoch 190/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3950
# Epoch 191/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3957
# Epoch 192/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3858
# Epoch 193/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3825
# Epoch 194/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3725
# Epoch 195/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3794
# Epoch 196/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3739
# Epoch 197/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3669
# Epoch 198/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3671
# Epoch 199/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3648
# Epoch 200/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.3563

# %%
scores = model.evaluate(X_test_pred, Y_test_pred)
# Out:
# 1/1 [==============================] - 0s 289ms/step - loss: 0.4925

# %%
I = 1
out = model.predict(X_test_pred)
plt.imshow(np.array(X_test)[I])
plt.show()
plt.imshow(np.array(Y_test)[I])
plt.show()
plt.imshow(convert_to_color(np.argmax(out[I], axis=-1)))
plt.show()
# Out:
# 1/1 [==============================] - 0s 22ms/step
